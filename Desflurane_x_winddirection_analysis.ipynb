# %%
import pandas as pd
import numpy as np

# %%
# Read in the desflurane data


# Note: -parse_dates converts to a numpy datetime object (so Python can understand the time coordinate)
#   - na_values tells pandas which entries are not numbers. Annoyingly there were some nan's with a space after them in this file
uob_des = pd.read_csv("UoB-desflurane_data.csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18388\971335391.py:6: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   uob_des = pd.read_csv("UoB-desflurane_data.csv",

# %%
# Drop NaN rows
uob_des = uob_des.dropna()

# %%
# Resample to 2-hourly
uob_des = uob_des.resample("2H").mean()

# %%
# Quick plot
uob_des.plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
# Import the required packages
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from math import pi

# !pip install windrose openpyxl
from windrose import WindroseAxes

# %%
df = pd.read_excel('Windrose_data.xlsx')

# %%
df
# Out:
#                     Date   Mean_WS     Mean_WD
# 0    2021-01-01 00:00:00  0.844625  175.807559
# 1    2021-02-01 00:00:00  1.025413  190.277888
# 2    2021-03-01 00:00:00  2.506910  289.780414
# 3    2021-04-01 00:00:00  2.906861  289.433961
# 4    2021-05-01 00:00:00  2.993984  288.693483
# ..                   ...       ...         ...
# 348     22/12/2021 00:00  1.409498  123.443208
# 349     23/12/2021 00:00  1.944781  204.217211
# 350     29/12/2021 10:25  2.965114  277.292953
# 351     30/12/2021 00:00  3.492437  245.932488
# 352     31/12/2021 00:00  2.466792  252.539852
#
# [353 rows x 3 columns]

# %%
print(df.columns)
# Out:
# Index(['Date', 'Mean_WS', 'Mean_WD'], dtype='object')

# %%
df['Mean_WS_x'] = df['Mean_WS'] * np.sin(df['Mean_WD'] * np.pi / 180.0)
df['Mean_WS_y'] = df['Mean_WS'] * np.cos(df['Mean_WD'] * np.pi / 180.0)
fig, ax = plt.subplots(figsize=(8, 8), dpi=80)
x0, x1 = ax.get_xlim()
y0, y1 = ax.get_ylim()
ax.set_aspect('equal')
df.plot(kind='scatter', x='Mean_WS_x', y='Mean_WD', alpha=0.35, ax=ax)
# Out:
# <Axes: xlabel='Mean_WS_x', ylabel='Mean_WD'>

# %%
df['Mean_WS'].hist(figsize=(10,6))
# Out:
# <Axes: >

# %%
#ax = WindroseAxes.from_ax()
#ax.box(df. Mean_WD, df. Mean_WS, bins=np.arange(0, 8, 1))
#ax.set_legend()

ax = WindroseAxes.from_ax()
ax.contourf(df.Mean_WD, df.Mean_WS, bins=np.arange(0, 8, 1), cmap=cm.hot)
ax.set_legend()

# %%
MHD_des = pd.read_csv("MHD-desflurane_data .csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18388\1956280408.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   MHD_des = pd.read_csv("MHD-desflurane_data .csv",

# %%
# Drop NaN rows
MHD_des = MHD_des.dropna()

# %%
# Resample to 2-hourly
MHD_des = MHD_des.resample("2H").mean()

# %%
MHD_des.plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
TAC_des = pd.read_csv("TAC-desflurane_data.csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18388\4087629625.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   TAC_des = pd.read_csv("TAC-desflurane_data.csv",

# %%
TAC_des = TAC_des.resample("2H").mean()

# %%
TAC_des.plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
#Cleaned data

# %%
           #UoB data

# %%
#UoB data between the dates 01/06/2021 and 16/09/2021
# Creating the same graphs as above so same code 

UoB_clean = pd.read_csv("Cleaned_UoB.csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )

# %%
UoB_clean = UoB_clean.dropna()

# %%
print(UoB_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 849 entries, 01/06/2021 02:39 to 16/09/2021 05:51
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   desflurane_ppt  849 non-null    float64
# dtypes: float64(1)
# memory usage: 13.3+ KB
# None

# %%
#ax.set_xlabel('Date')
#UoB_clean.plot()
#plt.xticks(rotation=45)

ax = UoB_clean.plot()

ax.set_xlabel('Date')
ax.set_ylabel ('Concentration of Desflurane (PPT)')

plt.xticks(rotation=10)

plt.show()

# %%
          #TAC data

# %%
#TAC data between the dates 01/06/2021 and 16/09/2021
# Creating the same graphs as above so same code 

TAC_clean = pd.read_csv("Cleaned_TAC.csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )

# %%
TAC_clean = TAC_clean.dropna()

# %%
print(TAC_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1284 entries, 01/06/2021 16:19 to 16/09/2021 20:34
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   desflurane_ppt  1284 non-null   float64
# dtypes: float64(1)
# memory usage: 20.1+ KB
# None

# %%
ax = TAC_clean.plot()

ax.set_xlabel('Date')
ax.set_ylabel ('Concentration of Desflurane (PPT)')

plt.xticks(rotation=10)

plt.show()

# %%
          #Cleaned MHD

# %%
#MHD data between the dates 01/06/2021 and 16/09/2021
# Creating the same graphs as above so same code 

MHD_clean = pd.read_csv("Cleaned_MHD.csv",
                parse_dates=[["date", "time"]],
                index_col="date_time",
                na_values=["nan", "nan "],
            )

# %%
MHD_clean = MHD_clean.dropna()

# %%
print(MHD_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1007 entries, 01/06/2021 17:04 to 16/09/2021 21:58
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   desflurane_ppt  1007 non-null   float64
# dtypes: float64(1)
# memory usage: 15.7+ KB
# None

# %%
ax = MHD_clean.plot()

ax.set_xlabel('Date')
ax.set_ylabel('Concentration of Desflurane (PPT)')
plt.xticks(rotation=10)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  [Text(-200.0, 0, '28/08/2021 06:56'),
#   Text(0.0, 0, '01/06/2021 17:04'),
#   Text(200.0, 0, '21/06/2021 11:37'),
#   Text(400.0, 0, '11/07/2021 10:18'),
#   Text(600.0, 0, '06/08/2021 15:28'),
#   Text(800.0, 0, '27/08/2021 15:46'),
#   Text(1000.0, 0, '16/09/2021 08:58'),
#   Text(1200.0, 0, '')])

# %%
# Notes on what I think i need to do from here 
# No 1 - Go through met data and create a line graph on wind speeds to put over the graph 
# Find met data for the locations of the other sites 
# Start looking at how to code the gaussian plume model 
#

# %%
# MET data work

# %%
# Bristol 1/06/2021- 16/09/2021

# %%
Bris_MET = pd.read_csv("Bristol_MET.csv")

# %%
print(Bris_MET.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              108 non-null    object
#  1   datetime          108 non-null    object
#  2   tempmax           108 non-null    float64
#  3   tempmin           108 non-null    float64
#  4   temp              108 non-null    float64
#  5   feelslikemax      108 non-null    float64
#  6   feelslikemin      108 non-null    float64
#  7   feelslike         108 non-null    float64
#  8   dew               108 non-null    float64
#  9   humidity          108 non-null    float64
#  10  precip            108 non-null    float64
#  11  precipprob        108 non-null    int64
#  12  precipcover       108 non-null    float64
#  13  preciptype        64 non-null     object
#  14  snow              0 non-null      float64
#  15  snowdepth         6 non-null      float64
# ...

# %%
# Average wind speed and direction for the time frame 
import matplotlib.dates as mdates 

x_axis = Bris_MET['datetime'] 
y_axis = Bris_MET['windspeed']

#plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=120))
#plt.gcf().autofmt_xdate()


ax.set_title('Manual DateFormatter', loc='left', y=0.85, x=0.02,
             fontsize='medium')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

plt.plot(x_axis, y_axis)
plt.title('Windspeed in Bristol (km/h)')
plt.xlabel('date')
plt.ylabel('speed')
plt.plot(x_axis,y_axis, color='red')


plt.show()

# %%
#Plot windspeed and PPT on the same graph 
#from datetime import datetime

#numeric_datetime = datetime.strptime("01/06/2021", "%d-%m-%y")

#x = Bris_MET['numeric_datetime']
#y1 = Bris_MET['windspeed']
#y2 = UoB_clean['desflurane_ppt']

#plt.plot(x, y1)
#plt.plot(x, y2)

#plt.show()


#UoB_clean = pd.read_csv("Cleaned_UoB.csv", parse_dates=[["date", "time"]],
                     #  index_col="date_time", na_values=["nan", "nan "])
#UoB_clean = UoB_clean.dropna()


#fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)


#x_axis_bris = Bris_MET['datetime']
#y_axis_bris = Bris_MET['windspeed']
#ax1.plot(x_axis_bris, y_axis_bris, color='blue')
#ax1.set_title('Windspeed in Bristol (km/h)')
#ax1.set_ylabel('Speed')


#x_axis_uob = UoB_clean.index
#y_axis_uob = UoB_clean['desflurane_ppt'] 
#ax2.plot(x_axis_uob, y_axis_uob, color='red')
#ax2.set_title('Windspeed in UoB Clean')
#ax2.set_ylabel('Desflurane level (ppt)')

#for ax in (ax1, ax2):
 #   for label in ax.get_xticklabels():
  #      label.set_rotation(45)
        #label.set_horizontalalignment('right')

#ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))


# why doesnt this want to work and align? THEY LITERALLY HAVE THE SAME DATES
#UoB_clean = UoB_clean.reindex(Bris_MET.index, fill_value=np.nan)

#plt.tight_layout()

#plt.show()

# %%
'''fig, ax1 = plt.subplots()
fig, ax2 = plt.subplots()


ax1.plot(UoB_clean.index, UoB_clean['desflurane_ppt'], label='Graph 1')
ax2.plot(Bris_MET.index, Bris_MET['windspeed'], label='Graph 2')


ax1.set_ylabel('Y-axis for Graph 1')
ax2.set_ylabel('Y-axis for Graph 2')
ax1.set_xlabel('X-axis for Graph 1')
ax2.set_xlabel('X-axis for Graph 2')
ax1.legend()
ax2.legend()


plt.show()'''
# Out:
# "fig, ax1 = plt.subplots()\nfig, ax2 = plt.subplots()\n\n\nax1.plot(UoB_clean.index, UoB_clean['desflurane_ppt'], label='Graph 1')\nax2.plot(Bris_MET.index, Bris_MET['windspeed'], label='Graph 2')\n\n\nax1.set_ylabel('Y-axis for Graph 1')\nax2.set_ylabel('Y-axis for Graph 2')\nax1.set_xlabel('X-axis for Graph 1')\nax2.set_xlabel('X-axis for Graph 2')\nax1.legend()\nax2.legend()\n\n\nplt.show()"

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(UoB_clean.index, UoB_clean['desflurane_ppt'], label='Desflurane')
ax2.plot(Bris_MET.index, Bris_MET['windspeed'], label='Windspeed')

ax1.set_ylabel('Desflurane ppt')
ax2.set_ylabel('Windspeed km/h')

ax2.set_xlabel('Date')

ax1.legend()
ax2.legend()

plt.show()

# %%
windb = list(Bris_MET['windspeed'])
max(windb)
# Out:
# 39.7

# %%
'''common_x_range = (min(UoB_clean.index), max(UoB_clean.index))
ax.set_xlim(common_x_range)
ax2.set_xlim(common_x_range)

#fig, ax = plt.subplots()

ax.plot(UoB_clean.index, UoB_clean['desflurane_ppt'], label='Graph 1', color='blue')

ax2 = ax.twinx()

ax2.plot(Bris_MET.index, Bris_MET['windspeed'], label='Graph 2', color='red')

ax.set_ylabel('Y-axis for Graph 1', color='blue')
ax2.set_ylabel('Y-axis for Graph 2', color='red')

ax.set_xlabel('X-axis')

lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax.legend(lines, labels, loc='best')

plt.show()'''
# Out:
# "common_x_range = (min(UoB_clean.index), max(UoB_clean.index))\nax.set_xlim(common_x_range)\nax2.set_xlim(common_x_range)\n\n#fig, ax = plt.subplots()\n\nax.plot(UoB_clean.index, UoB_clean['desflurane_ppt'], label='Graph 1', color='blue')\n\nax2 = ax.twinx()\n\nax2.plot(Bris_MET.index, Bris_MET['windspeed'], label='Graph 2', color='red')\n\nax.set_ylabel('Y-axis for Graph 1', color='blue')\nax2.set_ylabel('Y-axis for Graph 2', color='red')\n\nax.set_xlabel('X-axis')\n\nlines1, labels1 = ax.get_legend_handles_labels()\nlines2, labels2 = ax2.get_legend_handles_labels()\nlines = lines1 + lines2\nlabels = labels1 + labels2\nax.legend(lines, labels, loc='best')\n\nplt.show()"

# %%
#fig, ax = plt.subplots()

#ax.plot(x_axis_bris, y_axis_bris, label='Bris_MET', color='blue')

#ax.plot(x_axis_uob, y_axis_uob, label='UoB_clean', color='red')

#ax.set_title('Desflurane levels compared to windspeed')
#ax.set_xlabel('Date')
#ax.set_ylabel('Speed (km/h)')

#for label in ax.get_xticklabels():
 #   label.set_rotation(45)
  #  label.set_horizontalalignment('right')

#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))

#ax.legend()

#plt.show()

# %%
# Windrose diagram

# %%
if isinstance(Bris_MET.winddir, (int, float, np.float64)):
    print("Bris_MET.winddir is in the correct format (numeric).")
else:
    print("Bris_MET.winddir is not in the correct format.")
# Out:
# Bris_MET.winddir is not in the correct format.

# %%
# Convert string values to floats
numeric_winddir = [float(value) for value in Bris_MET.winddir]

# %%
if isinstance(Bris_MET.windspeed, (int, float, np.float64)):
    print("Bris_MET.windspeed is in the correct format (numeric).")
else:
    print("Bris_MET.windspeed is not in the correct format.")
# Out:
# Bris_MET.windspeed is not in the correct format.

# %%
numeric_windspeed = [float(value) for value in Bris_MET.windspeed]

# %%
if all(0 <= x <= 360 for x in Bris_MET.winddir):
    print("All values in Bris_MET.winddir are within the correct range.")
else:
    print("Some values in Bris_MET.winddir are outside the correct range.")
# Out:
# All values in Bris_MET.winddir are within the correct range.

# %%
if all(x >= 0 for x in Bris_MET.windspeed):
    print("All values in Bris_MET.windspeed are within the correct range (non-negative).")
else:
    print("Some values in Bris_MET.windspeed are outside the correct range.")
# Out:
# All values in Bris_MET.windspeed are within the correct range (non-negative).

# %%
if all(isinstance(x, (int, float, np.float64)) for x in Bris_MET.winddir if not np.isnan(x)):
    print("All values in Bris_MET.winddir are numeric and not missing.")
else:
    print("Some values in Bris_MET.winddir are non-numeric or missing.")
# Out:
# All values in Bris_MET.winddir are numeric and not missing.

# %%
if all(isinstance(x, (int, float, np.float64)) for x in Bris_MET.windspeed if not np.isnan(x)):
    print("All values in Bris_MET.windspeed are numeric and not missing.")
else:
    print("Some values in Bris_MET.windspeed are non-numeric or missing.")
# Out:
# All values in Bris_MET.windspeed are numeric and not missing.

# %%
#numeric_winddir = np.random.uniform(0, 360, 100)  
#numeric_windspeed = np.random.uniform(0, 10, 100)

ax = WindroseAxes.from_ax()
ax.contourf(numeric_winddir, numeric_windspeed, bins=np.arange(0, 40 ,4), cmap=cm.plasma)
ax.set_legend()

# %%
#MHD data

# %%
mhd_met = pd.read_csv("mace_head.csv")

# %%
# Average wind speed and direction for the time frame 
import matplotlib.dates as mdates 

x_axis = mhd_met['datetime'] 
y_axis = mhd_met['windspeed']

#plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=120))
#plt.gcf().autofmt_xdate()


ax.set_title('Manual DateFormatter', loc='left', y=0.85, x=0.02,
             fontsize='medium')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

plt.plot(x_axis, y_axis)
plt.title('Windspeed in Mace Head Ireland (km/h)')
plt.xlabel('date')
plt.ylabel('speed')
plt.plot(x_axis,y_axis, color='red')


plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(MHD_clean.index, MHD_clean['desflurane_ppt'], label='Graph 1')
ax2.plot(mhd_met.index, mhd_met['windspeed'], label='Graph 2')

ax1.set_ylabel('Y-axis for Graph 1')
ax2.set_ylabel('Y-axis for Graph 2')

ax2.set_xlabel('X-axis')

ax1.legend()
ax2.legend()

plt.show()

# %%
numeric_winddir1 = [float(value) for value in mhd_met.winddir]
numeric_windspeed1 = [float(value) for value in mhd_met.windspeed]

# %%
#numeric_winddir1 = np.random.uniform(0, 360, 100)  
#numeric_windspeed1 = np.random.uniform(0, 5, 100)

ax = WindroseAxes.from_ax()
ax.contourf(numeric_winddir1, numeric_windspeed1, bins=np.arange(0, 8 ,1), cmap=cm.hot)
ax.set_legend()

# %%
# TAC data

# %%
tac_met = pd.read_csv("East_anglea.csv")

# %%
# Average wind speed and direction for the time frame 
import matplotlib.dates as mdates 

x_axis = tac_met['datetime'] 
y_axis = tac_met['windspeed']

#plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=120))
#plt.gcf().autofmt_xdate()


ax.set_title('Manual DateFormatter', loc='left', y=0.85, x=0.02,
             fontsize='medium')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

plt.plot(x_axis, y_axis)
plt.title('Windspeed in East Anglea (km/h)')
plt.xlabel('date')
plt.ylabel('speed')
plt.plot(x_axis,y_axis, color='red')


plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(TAC_clean.index, TAC_clean['desflurane_ppt'], label='Graph 1')
ax2.plot(tac_met.index, tac_met['windspeed'], label='Graph 2')

ax1.set_ylabel('Y-axis for Graph 1')
ax2.set_ylabel('Y-axis for Graph 2')

ax2.set_xlabel('X-axis')

ax1.legend()
ax2.legend()

plt.show()

# %%
numeric_winddir2 = [float(value) for value in tac_met.winddir]
numeric_windspeed2 = [float(value) for value in tac_met.windspeed]

# %%
#numeric_winddir2 = np.random.uniform(0, 360, 100)  
#numeric_windspeed2 = np.random.uniform(0, 10, 100)

ax = WindroseAxes.from_ax()
ax.contourf(numeric_winddir2, numeric_windspeed2, bins=np.arange(0, 8 ,1), cmap=cm.hot)
ax.set_legend()

# %%
# WHAT NEXT
# Compare any days that have peaks with the wind speed and the desflurane levels to the wind direction
# then look at any geographical places around the recording stations that could be major contributors from the opposite direction to the wind direction 
#

# %%
# Initial thoughts: 
# 
# TAC:
# - very far away, big cities that are much closer - london, Birmingham.
# - North East of Bristol - looking for a Northeastern wind that correlates with a peak in both areas
# - close to Norwich - not super rural, expect the data to be less than bristol but not as low as MHD
# 
# 
# MHD 
# - even further, big cities that are closer - Dublin
# - North west of Bristol - look for a northwesterly wind that correlates with a peak in both areas 
# - very rural, no big towns/cities anywhere near it, expect it to be significantly lower than bristol and lower than TAC
# 
# because of the positions of the sites they can be compared with bristol separetly (as wind wouldnt be going in both directions at once)

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
# - UOB collected data only in 2021 and early 2022, missing data in the latter part of the year (2021) and early 2022. SIGNIFICANT SPIKES: mid april, Early July, early september. Large range, with lots of peaks and troughs, lowlying baseline value.
# 
# 
# - TAC data collected from 2017, a couple holes in early 2021 (March, April) and large hole in late 2021 (November to mid Jan). SIGNIFICANT SPIKES: early march, early may, early july, early october. smaller range than uob, more evenly distributed, but still with significant peaks and troughs  
# 
# 
# - MHD data colected from 2014 (possibly can do some comparisons between TAC and MHD earlier), No data recorded until June 2021, small hole in february 2022. SIGNIFICANT SPIKES: mid december, early september, late feb smaller peak - mid october, mid july.smaller range, distributed more evenly through

# %%
ax = sns.violinplot(data=UoB_clean,inner='quartile',color='white')
ax.set_ylabel('ppt')
#ax.set_title('UOB')


# The violin plot shows the distribution of the data, the vast majority of the values lie between 0 and 1, despite this the range is large, accounting for the occasional polluting event.
# Out:
# Text(0, 0.5, 'ppt')

# %%
ax2 = sns.violinplot(data=TAC_clean,inner='quartile',color='white')
ax2.set_ylabel('ppt')
ax2.set_title('TAC')
# Out:
# Text(0.5, 1.0, 'TAC')

# %%
ax3 = sns.violinplot(data=MHD_clean,inner='quartile',color='white')
ax3.set_ylabel('ppt')
ax3.set_title('MHD')
# Out:
# Text(0.5, 1.0, 'MHD')

# %%
# Finding the error

# %%
uob_error = UoB_clean.std()/np.sqrt(UoB_clean.count())
uob_error
# Out:
# desflurane_ppt    0.017844
# dtype: float64

# %%
tac_error = TAC_clean.std()/np.sqrt(TAC_clean.count())
tac_error
# Out:
# desflurane_ppt    0.000633
# dtype: float64

# %%
mhd_error = MHD_clean.std()/np.sqrt(MHD_clean.count())
mhd_error
# Out:
# desflurane_ppt    0.000459
# dtype: float64

# %%
uob25 = UoB_clean.quantile([0.25])
uob25
# Out:
#       desflurane_ppt
# 0.25           0.362

# %%
# Looking for a percentile that shows natural variations in the desfluorane ppt, at the 10th percentile, 
#there are large gaps in the data (not including the gaps due to imcomplete data), 
#the 50th percentile provides values for all periods of time measured while removing the peaks due to polluting events.

# %%
uob_sort = UoB_clean.sort_values(['desflurane_ppt'])
tac_sort = UoB_clean.sort_values(['desflurane_ppt'])
mhd_sort = UoB_clean.sort_values(['desflurane_ppt'])

uob_sort.dropna()
tac_sort.dropna()
mhd_sort.dropna()

uob_10 = uob_sort.head(173)
uob_25 = uob_sort.head(434)
uob_50 = uob_sort.head(867)
uob_75 = uob_sort.head(1301)
uob_90 = uob_sort.head(1561)
uob_95 = uob_sort.head(1647)
uob_100 = uob_sort.head(1734)


uob_10.plot()
plt.xticks(rotation=45)

uob_25.plot()
plt.xticks(rotation=45)

uob_50.plot()
plt.xticks(rotation=45)

uob_75.plot()
plt.xticks(rotation=45)

uob_90.plot()
plt.xticks(rotation=45)

uob_95.plot()
plt.xticks(rotation=45)

uob_100.plot()
plt.xticks(rotation=45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(-200.0, 0, '20/06/2021 22:14'),
#   Text(0.0, 0, '26/07/2021 17:02'),
#   Text(200.0, 0, '12/09/2021 02:50'),
#   Text(400.0, 0, '06/07/2021 10:15'),
#   Text(600.0, 0, '02/09/2021 17:35'),
#   Text(800.0, 0, '21/08/2021 15:46'),
#   Text(1000.0, 0, '')])

# %%
ax = uob_50.plot()

plt.xticks(rotation=10)

ax.set_xlabel('Date')
ax.set_ylabel('Concentration of Desflurane (PPT)')

plt.show()

# %%
tac_10 = tac_sort.head(258)
tac_25 = tac_sort.head(645)
tac_50 = tac_sort.head(1291)
tac_75 = tac_sort.head(1936)
tac_90 = tac_sort.head(2323)
tac_95 = tac_sort.head(2452)
tac_100 = tac_sort.head(2581)

tac_10.plot()
plt.xticks(rotation=45)

tac_25.plot()
plt.xticks(rotation=45)

tac_50.plot()
plt.xticks(rotation=45)

tac_75.plot()
plt.xticks(rotation=45)

tac_90.plot()
plt.xticks(rotation=45)

tac_95.plot()
plt.xticks(rotation=45)

tac_100.plot()
plt.xticks(rotation=45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(-200.0, 0, '20/06/2021 22:14'),
#   Text(0.0, 0, '26/07/2021 17:02'),
#   Text(200.0, 0, '12/09/2021 02:50'),
#   Text(400.0, 0, '06/07/2021 10:15'),
#   Text(600.0, 0, '02/09/2021 17:35'),
#   Text(800.0, 0, '21/08/2021 15:46'),
#   Text(1000.0, 0, '')])

# %%
# The range of values for TAC is much smaller
#- thus the lower percentiles do not provide an accurate representation of the natural variations over the year. 
#the 75th percentile provides data from froma all time periods measured while not including the high peaks due to polluting events.

# %%
mhd_10 = mhd_sort.head(254)
mhd_25 = mhd_sort.head(635)
mhd_50 = mhd_sort.head(1271)
mhd_75 = mhd_sort.head(1906)
mhd_90 = mhd_sort.head(2287)
mhd_95 = mhd_sort.head(2414)
mhd_100 = mhd_sort.head(2541)

mhd_10.plot()
plt.xticks(rotation=45)

mhd_25.plot()
plt.xticks(rotation=45)

mhd_50.plot()
plt.xticks(rotation=45)

mhd_75.plot()
plt.xticks(rotation=45)

mhd_90.plot()
plt.xticks(rotation=45)

mhd_95.plot()
plt.xticks(rotation=45)

mhd_100.plot()
plt.xticks(rotation=45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(-200.0, 0, '20/06/2021 22:14'),
#   Text(0.0, 0, '26/07/2021 17:02'),
#   Text(200.0, 0, '12/09/2021 02:50'),
#   Text(400.0, 0, '06/07/2021 10:15'),
#   Text(600.0, 0, '02/09/2021 17:35'),
#   Text(800.0, 0, '21/08/2021 15:46'),
#   Text(1000.0, 0, '')])

# %%
# The range of the mhd data is very small thus at the 90th percentile all values are still very close together, 
#using the 90th percentile as a baseline removes the small number of peaks produced by polluting events.

# %%
print(uob_10.mean())
print(uob_25.mean())
print(uob_50.mean())
print(uob_75.mean())
print(uob_90.mean())
print(uob_95.mean())
print(uob_100.mean())
# Out:
# desflurane_ppt    0.348382
# dtype: float64
# desflurane_ppt    0.362461
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64

# %%
print(tac_10.mean())
print(tac_25.mean())
print(tac_50.mean())
print(tac_75.mean())
print(tac_90.mean())
print(tac_95.mean())
print(tac_100.mean())
# Out:
# desflurane_ppt    0.353295
# dtype: float64
# desflurane_ppt    0.377696
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64

# %%
print(mhd_10.mean())
print(mhd_25.mean())
print(mhd_50.mean())
print(mhd_75.mean())
print(mhd_90.mean())
print(mhd_95.mean())
print(mhd_100.mean())
# Out:
# desflurane_ppt    0.353063
# dtype: float64
# desflurane_ppt    0.376638
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64
# desflurane_ppt    0.469449
# dtype: float64

# %%
# potential baseline values after looking at the graphs (natural variation occurs based on time of year):
# 
# UOB: 00.348382
# TAC: 0.353295 
# MHD: 0.353063

# %%
uob_high = UoB_clean.sort_values(['desflurane_ppt'], ascending = False)
tac_high = TAC_clean.sort_values(['desflurane_ppt'], ascending = False)
mhd_high = MHD_clean.sort_values(['desflurane_ppt'], ascending = False)

# %%
uob_1 = uob_high.head(10)
tac_1 = tac_high.head(10)
mhd_1 = mhd_high.head(10)

plt.plot(uob_1.index, uob_1['desflurane_ppt'], label = "uob") 
plt.plot(tac_1.index, tac_1['desflurane_ppt'], label = "tac") 
plt.legend() 
plt.show()
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
# Comparing the two data sets - we the curious and my data set that I found for bristol 
# Will help see if the met data is trustworthy or if there were problems with the data collection

# %%
bmet = pd.read_csv('We_the_curious_windrose.csv')
ax = WindroseAxes.from_ax()
ax.contourf(bmet.Mean_WD, bmet.Mean_WS, bins=np.arange(0, 5, 1), cmap=cm.plasma)
ax.set_legend()

# %%
print(bmet1.head())
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Bristol   01/06/2021     24.0     11.0  17.8          24.0          11.0
# 1  Bristol   02/06/2021     22.0     11.3  17.3          22.0          11.3
# 2  Bristol   03/06/2021     17.0     11.3  14.2          17.0          11.3
# 3  Bristol   04/06/2021     18.1      8.3  13.2          18.1           6.6
# 4  Bristol   05/06/2021     19.8      8.7  14.3          19.8           6.7
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       17.8   9.0      58.9  ...         49.6        9         NaN
# 1       17.3  11.9      71.4  ...         41.0        7         NaN
# 2       14.2  11.0      81.9  ...         35.4        7         NaN
# 3       13.0   7.0      68.1  ...         47.7        9         NaN
# 4       14.0   9.7      75.7  ...         47.0        9         NaN
#
#                sunrise               sunset  moonphase  \
# ...

# %%
bmet1 = pd.read_csv('Bris_found_met.csv')
ax = WindroseAxes.from_ax()
ax.box(bmet1.winddir, bmet1.windspeed, bins=np.arange(0, 20, 3), cmap=cm.plasma)
ax.set_legend()

# %%
print(UoB_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 849 entries, 01/06/2021 02:39 to 16/09/2021 05:51
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   desflurane_ppt  849 non-null    float64
# dtypes: float64(1)
# memory usage: 13.3+ KB
# None

# %%
#Looking at pollution data in the windrose plot pollution_data.csv

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.colors import BoundaryNorm
import pandas as pd
import numpy as np

##Variables to custom the graph
ftheta=50 #this is the number of subdivisions of angles in the graph
fr=16 #this is the number of subdivision of concentric circles in the graph
mapa='plasma' #Here can choose the colormap you prefer
nlevel=15 #This is the subdivisions of color and it depens of the values of pm array

data = pd.read_csv('pollution_data.csv')
data_theta = np.radians(data['wd'])
data_r = data['ws']
data_pm = data['desflurane_ppt']

eliminar=[]
for i in range(len(data_pm)):
    if np.isnan(data_pm[i]) or np.isnan(data_r[i]) or np.isnan(data_theta[i]):
        eliminar.append(i)
data_pm=np.delete(data_pm,eliminar)
data_r=np.delete(data_r,eliminar)
data_theta=np.delete(data_theta,eliminar)

##generate the subdivisions of the graph (the mesh)
theta = np.linspace(0,2*np.pi,ftheta)
r = np.linspace(min(data_r),max(data_r),fr)

##generate the mesh, that is a MxN matrix where i have coordinates of each point
Theta, R = np.meshgrid(theta, r)

##generate a circle around each point to take each point and assign it to each coordinate
dr=(r[1]-r[0])/2
dtheta=(theta[1]-theta[0])/2


C_pm=R*0

for i in range(len(Theta)):
    for j in range(len(Theta[0])):
        ##Number of elements to calculate the mean
        cantidad=0
        ##Sum of the values to calculate the mean
        suma=0
        ##I am inside the point and I iterate in the data
        for dato in range(len(data_pm)):
            if data_r[dato]<=(R[i][j]+dr) and data_r[dato]>(R[i][j]-dr) and data_theta[dato]<=(Theta[i][j]+dtheta) and data_theta[dato]>(Theta[i][j]-dtheta):
                suma=suma+data_pm[dato]
                cantidad=cantidad+1
        ## I can't divide by cero so I calculate the mean only if I can
        if cantidad!=0:
            promedio=suma/cantidad
        else:
            promedio=0
       
        C_pm[i][j]=promedio


levels = MaxNLocator(nbins=nlevel).tick_values(C_pm.min(), C_pm.max())

cmap = plt.get_cmap(mapa)

norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)


C_pm = np.ma.masked_less_equal(C_pm,0.05)


fig, ax = plt.subplots(subplot_kw={"projection":"polar"})


im=ax.pcolormesh(Theta, R, C_pm)

cbar=fig.colorbar(im, ax=ax)

#ax.set_title('Wind speed and direction from 01/06/2021-16/09/2021 against the concentration of desflurane ')

ax.set_theta_direction(-1)

ax.set_theta_offset(np.radians(90))

#ax.set_xticklabels(['N', 'NW',  'W', 'SW', 'S', 'SE','E', 'NE'])

cbar.set_label('PPT')

plt.show()

# increase size of bins and change the colour scale

# %%
# Private practices in clifton area - not large desflurane addition 
# More comparison with local areas. i.e. bristol 
# conclusion - Nuffield health? not really coming from the direction of the BRI
# small number of well made plots. Dont have to have all the information that you have collated FOCUS ON BIG PIC

# %%
# Almondsbury data

# %%
df3 = pd.read_csv('almondsbury_wind_data_back_up.csv')

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'], format='%d/%m/%Y %H:%M')

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'], dayfirst=True)

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'], format='mixed')

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'])
daily_average_WD = df3.groupby(df3['ob_end_time'].dt.date)['mean_wind_dir'].mean()
print (daily_average_WD)
# Out:
# ob_end_time
# 2021-01-01    276.250000
# 2021-01-02     85.000000
# 2021-01-03     44.166667
# 2021-01-04     45.416667
# 2021-01-05    162.500000
#                  ...
# 2021-12-27    132.083333
# 2021-12-28    237.500000
# 2021-12-29    197.916667
# 2021-12-30    209.583333
# 2021-12-31    201.666667
# Name: mean_wind_dir, Length: 365, dtype: float64

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'])
daily_average_WS = df3.groupby(df3['ob_end_time'].dt.date)['mean_wind_speed'].mean()
print (daily_average_WS)
# Out:
# ob_end_time
# 2021-01-01     2.708333
# 2021-01-02     5.041667
# 2021-01-03     7.208333
# 2021-01-04     8.875000
# 2021-01-05     4.166667
#                 ...
# 2021-12-27     5.750000
# 2021-12-28    10.625000
# 2021-12-29     9.458333
# 2021-12-30    10.875000
# 2021-12-31     9.166667
# Name: mean_wind_speed, Length: 365, dtype: float64

# %%
df3['ob_end_time'] = pd.to_datetime(df3['ob_end_time'])
daily_average_time_WS = df3.groupby(df3['ob_end_time'].dt.time)['mean_wind_speed'].mean()
print (daily_average_time_WS)
# Out:
# ob_end_time
# 00:00:00    5.646575
# 01:00:00    5.594521
# 02:00:00    5.410959
# 03:00:00    5.413699
# 04:00:00    5.405479
# 05:00:00    5.473973
# 06:00:00    5.663014
# 07:00:00    5.936986
# 08:00:00    6.342466
# 09:00:00    6.821918
# 10:00:00    7.293956
# 11:00:00    7.713499
# 12:00:00    8.085165
# 13:00:00    8.415978
# 14:00:00    8.387363
# 15:00:00    8.280220
# 16:00:00    8.027397
# 17:00:00    7.712329
# 18:00:00    7.347945
# 19:00:00    6.835616
# 20:00:00    6.397260
# 21:00:00    6.191781
# 22:00:00    5.901370
# 23:00:00    5.761644
# Name: mean_wind_speed, dtype: float64

# %%
daily_average_time_WS.index = daily_average_time_WS.index.map(lambda x: x.hour + x.minute / 60)

# %%
plt.figure(figsize=(18, 6))
plt.plot(daily_average_time_WS.index, daily_average_time_WS.values,marker='o', linestyle='-')
xtick_positions = range(0, 24)  # 25 positions to include 24:00
xtick_labels = [f"{hour:02d}:00" for hour in xtick_positions]
plt.xticks(xtick_positions, xtick_labels)
plt.xlabel('Time of Day')
plt.ylabel('Average wind speed')
plt.title('Average wind speeds during the day')
# Out:
# Text(0.5, 1.0, 'Average wind speeds during the day')

# %%
ax = WindroseAxes.from_ax()
ax.contourf(df3.mean_wind_dir, df3.mean_wind_speed, normed=True, edgecolor='white')
ax.set_legend() #(title="Wind Speed (knots)", loc=(1.1, 0))
#plt.title('Almondsbury windrose plot')

#df3 = pd.read_csv('almondsbury_wind_data_back_up.csv')
#ax = WindroseAxes.from_ax()
#ax.contourf(df3.mean_wind_dir, df3.mean_wind_speed, bins=np.arange(0, 5, 1), cmap = cm.coolwarm)
#ax.set_legend()
